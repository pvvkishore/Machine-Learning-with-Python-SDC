# %% [markdown]
# # Objective: Using a real-world dataset(Wholesale / Mall / Online Retail), learners will build a complete unsupervised clustering workflow with K-Means—from data preparation to cluster interpretation—by
# ## (1) Training K-Means models across varying K and varying initializations,
# ## (2) Evaluating clustering quality using SSE/Inertia, Silhouette, Davies–Bouldin, and Calinski–Harabasz,
# ## (3) Visualizing results using PCA scatter plots, elbow curves, silhouette trends, centroid heatmaps, and feature-wise cluster comparisons, and
# ## (4) Selecting a robust, interpretable final clustering solution that balances compactness, separation, stability, and explainability.
